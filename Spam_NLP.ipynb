# %%
import re
import pandas as pd
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords 
from nltk.stem import WordNetLemmatizer

# %%
data={"email":["Click here to win a lottery prize.",
               "Work from home ,no prior experience required.",
               "Call on this number to make payment.",
               "Loan on less interest rate,Click Here.",
               "Amazon Gift card worth Rs.500. Grab it now!.",
               "Urgent!Get your KYC done in 24 -48 hr.",
               "I phone starting from Rs.10k, limited offer, Buy now!.",
               "Get your Aadhar card verified on this portal, CLick here. From PMO Office.",
               "We processed your AppNo. 92732. youir Profile is macthed with Infosys & Genpact Openings. Click here to apply now.",
               "Start your session at DUO Lingo. Click here!",
               "A Next Skill is Just a Click Away. Simplilearn ",
               "Your Google Acoount was Logged in in a different device.",
               "Your Google Account was successfully recovered. Review now." 
              ],
      "label":["spam","spam","spam","spam","not spam","spam","spam","spam","spam","not spam","not spam","not spam","not spam"]
      }

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#                                                 email     label
# 0                  Click here to win a lottery prize.      spam
# 1       Work from home ,no prior experience required.      spam
# 2                Call on this number to make payment.      spam
# 3              Loan on less interest rate,Click Here.      spam
# 4        Amazon Gift card worth Rs.500. Grab it now!.  not spam
# 5              Urgent!Get your KYC done in 24 -48 hr.      spam
# 6   I phone starting from Rs.10k, limited offer, B...      spam
# 7   Get your Aadhar card verified on this portal, ...      spam
# 8   We processed your AppNo. 92732. youir Profile ...      spam
# 9        Start your session at DUO Lingo. Click here!  not spam
# 10    A Next Skill is Just a Click Away. Simplilearn   not spam
# 11  Your Google Acoount was Logged in in a differe...  not spam
# 12  Your Google Account was successfully recovered...  not spam

# %%
def clean(text):
    text=text.lower()
    text=re.sub(r'[^\w\s]','',text)
    tokens=word_tokenize(text)
    tokens=[WordNetLemmatizer().lemmatize(word) for word in tokens]
    tokens=[word for word in tokens if word not in stopwords.words('english')]
    return "".join(tokens)

# %%
df['email']=df['email'].apply(clean)

# %%
df
# Out:
#                                                 email     label
# 0                                clickwinlotteryprize      spam
# 1                     workhomepriorexperiencerequired      spam
# 2                               callnumbermakepayment      spam
# 3                           loanlessinterestrateclick      spam
# 4                        amazongiftcardworthrs500grab  not spam
# 5                              urgentgetkycdone2448hr      spam
# 6                   phonestartingrs10klimitedofferbuy      spam
# 7           getaadharcardverifiedportalclickpmooffice      spam
# 8   processedappno92732youirprofilemacthedinfosysg...      spam
# 9                           startsessionduolingoclick  not spam
# 10                      nextskillclickawaysimplilearn  not spam
# 11               googleacoountwaloggeddifferentdevice  not spam
# 12         googleaccountwasuccessfullyrecoveredreview  not spam

# %%
x_train,x_test,y_train,y_test=train_test_split(df['email'],df['label'],test_size=0.2, random_state=42)

# %%
pipneline=Pipeline([('tfidf',TfidfVectorizer()),('Classifier',MultinomialNB())])

# %%
pipeline.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('Classifier', MultinomialNB())])

# %%
user_email=input("Enter you email:")
cleaned_email=clean(user_email)
predict=pipeline.predict([cleaned_email])
print("Result:",predict[0])
# Out:
# Enter you email: Subject: enron methanol ; meter # : 988291\r\n...
# Result: spam

# %%
df=pd.read_csv('spam_ham_dataset.csv')

# %%
df
# Out:
#          label                                              email
# 0     Not Spam  Subject: enron methanol ; meter # : 988291\r\n...
# 1     Not Spam  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2     Not Spam  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3         spam  Subject: photoshop , windows , office . cheap ...
# 4     Not Spam  Subject: re : indian springs\nthis deal is to ...
# ...        ...                                                ...
# 5166  Not Spam  Subject: put the 10 on the ft\r\nthe transport...
# 5167  Not Spam  Subject: 3 / 4 / 2000 and following noms\r\nhp...
# 5168  Not Spam  Subject: calpine daily gas nomination\r\n>\r\n...
# 5169  Not Spam  Subject: industrial worksheets for august 2000...
# 5170      spam  Subject: important online banking alert\r\ndea...
#
# [5171 rows x 2 columns]

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#                                                 email     label
# 0                  Click here to win a lottery prize.      spam
# 1       Work from home ,no prior experience required.      spam
# 2                Call on this number to make payment.      spam
# 3              Loan on less interest rate,Click Here.      spam
# 4        Amazon Gift card worth Rs.500. Grab it now!.  not spam
# 5              Urgent!Get your KYC done in 24 -48 hr.      spam
# 6   I phone starting from Rs.10k, limited offer, B...      spam
# 7   Get your Aadhar card verified on this portal, ...      spam
# 8   We processed your AppNo. 92732. youir Profile ...      spam
# 9        Start your session at DUO Lingo. Click here!  not spam
# 10    A Next Skill is Just a Click Away. Simplilearn   not spam
# 11  Your Google Acoount was Logged in in a differe...  not spam
# 12  Your Google Account was successfully recovered...  not spam
